# %%
from astropy.io import fits

import matplotlib
import matplotlib.pyplot as plt

# Plotting style
matplotlib.rcParams.update({'font.size': 14})
plt.style.use('tableau-colorblind10')

# Set up some plotting defaults:

params = {'axes.labelsize': 13,
          'font.size': 14,
          'legend.fontsize': 12,
          'xtick.major.width': 1.5,
          'xtick.minor.width': 1,
          'xtick.major.size': 6,
          'xtick.minor.size': 3,
          'xtick.direction': 'in',
          'xtick.top': True,
          'lines.linewidth': 1.5,
          'axes.linewidth': 1.5,
          'axes.labelweight': 1.5,
          'axes.titleweight': 1.5,
          'ytick.major.width': 1.5,
          'ytick.minor.width': 1,
          'ytick.major.size': 6,
          'ytick.minor.size': 3,
          'ytick.direction': 'in',
          'ytick.right': True,
          'figure.figsize': [7, 7],
          'figure.facecolor': 'White'
          }

plt.rcParams.update(params)

# %%
h = fits.open("/global/homes/a/ambrough/bfxshear/data/catsim/stars_med_june2018.fits")

# %%
h.info()
# Out:
# Filename: /global/homes/a/ambrough/bfxshear/data/catsim/stars_med_june2018.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     30   20667R x 11C   [K, D, D, D, D, D, D, D, D, D, D]

# %%
h[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   88 / length of dimension 1
# NAXIS2  =                20667 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   11 / number of table fields
# TTYPE1  = 'startileid'
# TFORM1  = 'K       '
# TTYPE2  = 'ra      '
# TFORM2  = 'D       '
# TTYPE3  = 'dec     '
# TFORM3  = 'D       '
# TTYPE4  = 'redshift'
# TFORM4  = 'D       '
# TTYPE5  = 'fluxnorm_star'
# TFORM5  = 'D       '
# TTYPE6  = 'u_ab    '
# TFORM6  = 'D       '
# TTYPE7  = 'g_ab    '
# TFORM7  = 'D       '
# TTYPE8  = 'r_ab    '
# TFORM8  = 'D       '
# TTYPE9  = 'i_ab    '
# TFORM9  = 'D       '
# TTYPE10 = 'z_ab    '
# TFORM10 = 'D       '
# TTYPE11 = 'y_ab    '
# TFORM11 = 'D       '

# %%
print(len(h[1].data['u_ab']))
# Out:
# 20667

# %%
_ = plt.hist(h[1].data['u_ab'], color="blue", histtype="step",bins=75, alpha=0.5, label="u")
_ = plt.hist(h[1].data['g_ab'], color="green", histtype="step", bins=75, alpha=0.5, label="g")
_ = plt.hist(h[1].data['r_ab'], color="orange", histtype="step", bins=75, alpha=0.5, label="r")
_ = plt.hist(h[1].data['i_ab'], color="yellow", histtype="step", bins=75, alpha=0.5, label="i")
_ = plt.hist(h[1].data['z_ab'], color="red", histtype="step", bins=75, alpha=0.5, label="z")
_ = plt.hist(h[1].data['y_ab'], color="brown", histtype="step", bins=75, alpha=0.5, label="y")
plt.xlabel(r"$m_{\mathrm{AB}}$")
plt.legend(frameon=False)
